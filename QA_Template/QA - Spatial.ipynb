# %%
import guidance
import sys
import re
import json
from guidance import models, gen, user, assistant, system

# %%
with system():
    gpt = models.OpenAI("gpt-4")
    lm = gpt + '''You are a road safety scientist at a vehicle company with a background in traffic engineering, 
    civil engineering and autonomous vehicles. I have a road driving scenario ontology as shown below (in DOT format). 
    
    digraph Ontology { 
    EnvironmentalConditions -> WeatherConditions;
    EnvironmentalConditions -> LightingConditions;
    EnvironmentalConditions -> RoadSurfaceConditions;
    EnvironmentalConditions -> TimeOfDay;
    EnvironmentalConditions -> Season;
    RoadTopologyAndTrafficInfrastructure -> RoadType;
    RoadTopologyAndTrafficInfrastructure -> RoadSigns;
    RoadTopologyAndTrafficInfrastructure -> TrafficLights;
    RoadTopologyAndTrafficInfrastructure -> PedestrianCrossings;
    RoadTopologyAndTrafficInfrastructure -> Junction -> Roundabout;
    RoadTopologyAndTrafficInfrastructure -> Junction -> Intersection;
    RoadTopologyAndTrafficInfrastructure -> RoadMarkings;
    RoadTopologyAndTrafficInfrastructure -> SpeedLimit;
    RoadTopologyAndTrafficInfrastructure -> TrafficCongestion;
    RoadTopologyAndTrafficInfrastructure -> RoadWorks;
    RoadTopologyAndTrafficInfrastructure -> ParkingZones;
    RoadTopologyAndTrafficInfrastructure -> Bridge;
    RoadTopologyAndTrafficInfrastructure -> Tunnel;
    RoadTopologyAndTrafficInfrastructure -> TrafficCameras;
    RoadTopologyAndTrafficInfrastructure -> SchoolZones;
    TrafficParticipantAndBehavior -> Vehicle -> AutonomousVehicle;
    TrafficParticipantAndBehavior -> Vehicle -> ManualVehicle;
    TrafficParticipantAndBehavior -> Vehicle -> EmergencyVehicle;
    TrafficParticipantAndBehavior -> Vehicle -> CommercialVehicle;
    TrafficParticipantAndBehavior -> Vehicle -> Motorcycle;
    TrafficParticipantAndBehavior -> Vehicle -> PublicTransportation;
    Vehicle -> VehicleSafetyFeatures;
    Vehicle -> VehicleSize;
    Vehicle -> VehicleType;
    Vehicle -> VehicleAge;
    Vehicle -> VehicleCondition;
    Vehicle -> VehicleLoad;
    TrafficParticipantAndBehavior -> Pedestrian;
    TrafficParticipantAndBehavior -> Cyclist;
    TrafficParticipantAndBehavior -> DriverBehavior;
    TrafficParticipantAndBehavior -> PedestrianBehavior;
    TrafficParticipantAndBehavior -> CyclistBehavior;
    TrafficParticipantAndBehavior -> TrafficRulesAdherence;
    TrafficParticipantAndBehavior -> Animal;
    TrafficParticipantAndBehavior -> DriverDistraction;
    TrafficParticipantAndBehavior -> DriverFatigue;
    TrafficParticipantAndBehavior -> DriverExperience;
    TrafficParticipantAndBehavior -> DriverVision;
    TrafficParticipantAndBehavior -> DriverIntoxication;
    TrafficParticipantAndBehavior -> DriverAge;
    }
    
    Here is some additional information about multiple-choice question formation as well as Bloom's taxonomy: 
    A multiple choice question is a short question aimed at assessing the student's learning regarding a particular set of concepts.
    The questions can be of the form of that clearly assesses specific reasoning skills as demonstrated below. Each question has two types of
    answer choices: a stem (which is the correct choice) and distractors. The questions and choices must be short and the student must be able to answer in 5 minutes.
    The distractors are incorrect answer choices. Ensure that you create a question with one stem and 3 distractors. The answer choices
    must be labeled A to D. Ensure that at least one distractor is close to the stem but still the incorrect choice.

    The multiple choice questions must assess the learning of students regarding the concepts stated above. The learning goals
    pertaining to the reasoning skills are categorized from concrete to abstract in Bloom's Taxonomy. Here are the six levels of Bloom’s taxonomy and their definitions. Each successive category is more abstract than the previous one:
    
    * Remember - The associated action verbs are recognizing, recalling, recollecting and remembering
    * Understand - The associated action verbs are interpreting, exemplifying, classifying, summarizing, inferring, comparing, and explaining.
    * Apply - The associated action verbs are executing and implementing. 
    * Analyze - The associated action verbs are differentiating and attributing.
    * Evaluate - The associated action verbs are checking and critiquing. 
    * Create - The associated action verbs are generating, planning and producing.

    Given information about the traffic related ontology, as well as question formation guidelines and Bloom's taxonomy, 
    would you be able to create multiple-choice questions for EACH TYPE OF INFERENCE provided below that fulfill the MCQ 
    guidelines as well as Bloom's taxonomy skills. The below example shows the type of inference relation as well as an example 
    of the types of questions asked with that particular relation. For option D, make sure the option is similar to the answer to the question, however incorrect. 

    Typical spatial reasoning relations that can be drawn based on the example below
    Spatial relations: Relative positions.
    Formal method relation property: Transitivity. 
    Question: My vehicle is stopped on the street. A vehicle is parked in a top-right position based on a bird's eye view from my vehicle. A bike is parked in front of it. 
    What is the bike's position relative to my own? (A) Bottom right (B) Bottom left (C) Top right (D) Top left.

    The notion of reasoning hops is provided:
    Example of a question with one reasoning hop: What is the result of a vehicle colliding with a bike?
    Example of a question with two reasoning hops: What is the response of the vehicle's driver to the result of the vehicle colliding with the bike?
    Example of a question with three reasoning hops: What is the response of the vehicle to the back of the vehicle to a vehicle that is responding to the result of it colliding with the bike?

    Generate a traffic scenario from the concepts and relations listed above. Then generate ten multiple choice questions in accordance with the details above.
    Focus on the Bloom's taxonomy term "understand" detailed above for 1 questions, on Bloom's taxonomy term "apply" detailed above for 1 questions, Bloom's taxonomy term "evaluate" detailed above for 1 questions and Bloom's taxonomy term "create" detailed above for 1 question.  
    Focus on the spatial reasoning concept detailed above. Ensure that 1 question require 1 reasoning hop of this type to answer, One question require 2 reasoning hops of this type to answer and three questions require 3 reasoning hops of this type to answer. 
    Generate only the scenario and the multiple choice questions. There should not be any redundancy among questions or the answer choices for different questions.
    Ensure that questions are asking very different questions. After each question, think carefully and write an rationale to answer the question followed by the correct answer choice.


    '''
    
with assistant():
    lm += gen('explanation', temperature=0.4, max_tokens=700)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a road safety scientist at a vehicle company with a background in traffic engineering,
#     civil engineering and autonomous vehicles. I have a road driving scenario ontology as shown below (in DOT format).
#
#     digraph Ontology {
#     EnvironmentalConditions -&gt; WeatherConditions;
#     EnvironmentalConditions -&gt; LightingConditions;
#     EnvironmentalConditions -&gt; RoadSurfaceConditions;
# ...
